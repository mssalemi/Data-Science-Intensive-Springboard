# %%
# %matplotlib inline

import pandas as pd
import numpy as np

import scipy.stats as stats
import matplotlib.pyplot as plt
import sklearn

from sklearn.linear_model import LinearRegression

# %%
d = {
    'Sales': [100,250,275,200,300],
    'GDP': [1.0,1.9,2.4,2.6,2.9]
}
df = pd.DataFrame(data=d)

# %%
plt.scatter(df.GDP, df.Sales)
plt.title('Relationship between Sales and GDP')
plt.xlabel('GDP')
plt.ylabel('Sales')

# %%
X = df.drop('Sales', axis=1)
X
# Out:
#    GDP
# 0  1.0
# 1  1.9
# 2  2.4
# 3  2.6
# 4  2.9

# %%
lm1 = LinearRegression()
lm1.fit(X,df.Sales)
temp = list(zip(X.columns, lm1.coef_))
pd.DataFrame(temp, columns=['features',  'estimatedCoefficients'])
# Out:
#   features  estimatedCoefficients
# 0      GDP              88.155515

# %%
plt.scatter(df.GDP, df.Sales)
plt.title('Relationship between Sales and GDP with Fit')
plt.xlabel('GDP')
plt.ylabel('Sales')
plt.plot(df.GDP, lm.predict(X), color='blue', linewidth = 3)

# %%
mmseLM1 = np.mean((df.Sales - lm1.predict(X))**2)
mmseLM1
# Out:
# 1183.9963833634727

# %%
lm = LinearRegression()
lm.fit(df[['GDP']], df[['Sales']])
slope = lm.coef_[0]
yint = lm.intercept_

# %%
x1 = 0
y1 = yint
x2 = 1
y2 = yint + slope

# %%
plt.scatter(df.GDP, df.Sales)
plt.title('Relationship between Sales and GDP')
plt.xlabel('GDP')
plt.ylabel('Sales')
plt.plot(df.GDP, lm.predict(df[['GDP']]), color='blue', linewidth=3)

# %%
X = df.drop('Sales', axis = 1)
X
# Out:
#    GDP  Year
# 0  1.0  2005
# 1  1.9  2006
# 2  2.4  2007
# 3  2.6  2008
# 4  2.9  2009
