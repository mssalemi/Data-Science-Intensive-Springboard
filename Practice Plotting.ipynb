# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
baseFilePath = "/Users/mehdisalemi/Desktop/Data Science Intensive/DataSets/Stocks/"
stocks = ["TWTR"]
dates = pd.date_range(start="2016-01-01", end="2016-07-13")

# %%
file = baseFilePath + "TWTR.csv"
df = pd.read_csv(file)
plt.hist(df.Close.dropna())
# Out:
# (array([ 1.,  2.,  3.,  4.,  0.,  2.,  3.,  2.,  2.,  2.]),
#  array([ 15.36 ,  15.634,  15.908,  16.182,  16.456,  16.73 ,  17.004,
#          17.278,  17.552,  17.826,  18.1  ]),
#  <a list of 10 Patch objects>)

# %%
sns.boxplot(df.Close)

# %%
sns.kdeplot(df.Close, shade=True)

# %%
sns.distplot(df.Close)

# %%
sns.kdeplot(df.Close, cumulative=True)
