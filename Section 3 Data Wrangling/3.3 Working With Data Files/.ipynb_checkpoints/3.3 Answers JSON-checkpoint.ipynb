# %% [markdown]
# # Answers to the JSON Excercises

# %%
import pandas as pd
import numpy as np

import json
from pandas.io.json import json_normalize

# %% [markdown]
# ### Excercise
# ##### Using data in file 'data/world_bank_projects.json' and the techniques demonstrated above,
# + 1. Find the 10 countries with most projects
# + 2. Find the top 10 major project themes (using column 'mjtheme_namecode')
# + 3. In 2. above you will notice that some entries have only the code and the name is missing. Create a dataframe with the missing names filled in.

# %%
sample_json_df = pd.read_json('data/world_bank_projects.json')
sample_json_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-4c03be4ec5e6> in <module>()
# ----> 1 sample_json_df = pd.read_json('world_bank.json')
#       2 sample_json_df.head()
#
# /Users/mehdisalemi/anaconda/lib/python3.5/site-packages/pandas/io/json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit)
#     209         obj = FrameParser(json, orient, dtype, convert_axes, convert_dates,
#     210                           keep_default_dates, numpy, precise_float,
# --> 211                           date_unit).parse()
#     212
#     213     if typ == 'series' or obj is None:
#
# /Users/mehdisalemi/anaconda/lib/python3.5/site-packages/pandas/io/json.py in parse(self)
#     277
#     278         else:
# --> 279             self._parse_no_numpy()
#     280
#     281         if self.obj is None:
#
# /Users/mehdisalemi/anaconda/lib/python3.5/site-packages/pandas/io/json.py in _parse_no_numpy(self)
#     494         if orient == "columns":
#     495             self.obj = DataFrame(
# --> 496                 loads(json, precise_float=self.precise_float), dtype=None)
#     497         elif orient == "split":
#     498             decoded = dict((str(k), v)
#
# ValueError: Trailing data
